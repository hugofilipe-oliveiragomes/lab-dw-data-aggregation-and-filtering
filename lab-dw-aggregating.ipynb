# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
url = ("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv")
df = pd.read_csv(url)

# %%
display(df.head())
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df.columns = ['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
       'Response', 'Coverage', 'Education', 'Effective To Date',
       'EmploymentStatus', 'Gender', 'Income', 'Location Code',
       'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
       'Months Since Policy Inception', 'Number of Open Complaints',
       'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
       'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
       'Vehicle Type']

# %%
df.rename(columns={col: col.replace(" ", "_").lower() for col in df.columns}, inplace=True)

# %%
display(df)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df["customer_lifetime_value"] = df["customer_lifetime_value"].round(2)

# %%
display(df)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona                  4809.22       No
# 1               1  KX64629  California                  2228.53       No
# 2               2  LZ68649  Washington                 14947.92       No
# 3               3  XL78013      Oregon                 22332.44      Yes
# 4               4  QA50777      Oregon                  9025.07       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada                 15563.37       No
# 10906       10906  KX53892      Oregon                  5259.44       No
# 10907       10907  TL39050     Arizona                 23893.30       No
# 10908       10908  WA60547  California                 11971.98       No
# 10909       10909  IV32877         NaN                  6857.52      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
filtered_df = df[(df['total_claim_amount'] > 1000) & (df['response'] == 'Yes')]
filtered_df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 189           189  OK31456  California                 11009.13      Yes
# 236           236  YJ16163      Oregon                 11009.13      Yes
# 419           419  GW43195      Oregon                 25807.06      Yes
# 442           442  IP94270     Arizona                 13736.13      Yes
# 587           587  FJ28407  California                  5619.69      Yes
# ...           ...      ...         ...                      ...      ...
# 10351       10351  FN44127      Oregon                  3508.57      Yes
# 10373       10373  XZ64172      Oregon                 10963.96      Yes
# 10487       10487  IX60941      Oregon                  3508.57      Yes
# 10565       10565  QO62792      Oregon                  7840.17      Yes
# 10708       10708  CK39096      Oregon                  5619.69      Yes
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
df_filtered2 = df[df['response'] == 'Yes']

# %%
display (df_filtered2)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 3               3  XL78013      Oregon                 22332.44      Yes
# 8               8  FM55990  California                  5989.77      Yes
# 15             15  CW49887  California                  4626.80      Yes
# 19             19  NJ54277  California                  3746.75      Yes
# 27             27  MQ68407      Oregon                  4376.36      Yes
# ...           ...      ...         ...                      ...      ...
# 10844       10844  FM31768     Arizona                  5979.72      Yes
# 10852       10852  KZ80424  Washington                  8382.48      Yes
# 10872       10872  XT67997  California                  5979.72      Yes
# 10887       10887  BY78730      Oregon                  8879.79      Yes
# 10897       10897  MM70762     Arizona                  9075.77      Yes
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
df_filtered2.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1466 entries, 3 to 10897
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     1466 non-null   int64
#  1   customer                       1466 non-null   object
#  2   state                          1466 non-null   object
#  3   customer_lifetime_value        1466 non-null   float64
#  4   response                       1466 non-null   object
#  5   coverage                       1466 non-null   object
#  6   education                      1466 non-null   object
#  7   effective_to_date              1466 non-null   object
#  8   employmentstatus               1466 non-null   object
#  9   gender                         1466 non-null   object
#  10  income                         1466 non-null   int64
#  11  location_code                  1466 non-null   object
# ...

# %%
import numpy as np

# %%
df_filtered2.groupby(['gender', 'policy_type'])['total_claim_amount'].mean()
# Out:
# gender  policy_type
# F       Corporate Auto    433.738462
#         Personal Auto     452.966037
#         Special Auto      453.279714
# M       Corporate Auto    408.582468
#         Personal Auto     457.010149
#         Special Auto      429.528125
# Name: total_claim_amount, dtype: float64

# %% [markdown]
# # Gender Differences:
#
# Female Customers:
# On average, female customers have higher total claim amounts compared to male customers for corporate and special auto policies. The average total claim amounts for female customers are 433.74 for corporate auto, 452.97 for personal auto, and 453.28 for special auto.
#
# Male Customers:
# Male customers have a slightly higher average total claim amount for personal auto policies at 457.01, but lower for corporate auto (408.58) and special auto (429.53) compared to females.

# %% [markdown]
# # Policy Type Impact:
#
# Female customers:
# The claim amounts are relatively similar across different policy types, with a slightly higher average for special auto policies.
# Male customers:
# Personal auto policies have the highest average total claim amount, indicating a trend where claims under personal auto policies are higher for men.

# %% [markdown]
# # Overall Insights:
#
# The claim amounts are fairly consistent across genders and policy types, with personal auto policies yielding slightly higher average claim amounts, particularly for male customers.
# There's a noticeable gender difference in claim amounts for corporate auto policies, with female customers filing higher claims on average than male customers. This could be indicative of different usage patterns, risk profiles, or vehicle types insured under these policies.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
state_customer_count = df['state'].value_counts()
states_more_than_500_customers = state_customer_count[state_customer_count > 500]
display(states_more_than_500_customers)
# Out:
# state
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: count, dtype: int64

# %% [markdown]
# # I am not sure that this is the supposed output...
#
# In summary, California, Oregon, Arizona, Nevada, and Washington are key markets for the insurance company, with each state hosting a significant number of policyholders. Strategies for these states should focus on strengthening market presence, enhancing customer relationships, and exploring avenues for further growth and efficiency improvements

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
agg_results = df.groupby(['gender', 'education']).agg({
    'customer_lifetime_value': ['max', 'min', 'median']})
display(agg_results)
# Out:
#                             customer_lifetime_value
#                                                 max      min    median
# gender education
# F      Bachelor                            73225.96  1904.00  5640.505
#        College                             61850.19  1898.68  5623.610
#        Doctor                              44856.11  2395.57  5332.460
#        High School or Below                55277.45  2144.92  6039.555
#        Master                              51016.07  2417.78  5729.860
# M      Bachelor                            67907.27  1898.01  5548.030
#        College                             61134.68  1918.12  6005.850
#        Doctor                              32677.34  2267.60  5577.670
#        High School or Below                83325.38  1940.98  6286.735
#        Master                              50568.26  2272.31  5579.100

# %% [markdown]
# The provided data outlines the maximum, minimum, and median customer lifetime value, segmented by gender and education level. Analyzing this data reveals several insights into the demographics of an insurer's customer base and their potential value to the company.

# %% [markdown]
# # Gender and Education
#
# Highest customer lifetime value:
# The highest maximum is observed in male customers with a High School or Below education level at 83,325.38.
#
# Lowest customer lifetime value:
# The lowest minimum is found in female customers with a Bachelor's degree at 1,904.00.

# %% [markdown]
# # Median
#
# Female Customers:
# The median customer lifetime value is relatively consistent across different education levels, with High School or Below having the highest median with 6,039.555.
# Bachelor and College-educated female customers have slightly lower median customer lifetime values.
#
# Male Customers:
# High School or Below education have the highest median customer lifetime value with 6,286.735, closely followed by those with a College education.
# The Doctor category shows the lowest maximum customer lifetime value for males.

# %% [markdown]
# # Education Level Variation:
#
# Doctorate Level: Notably, individuals with a Doctorate show a significant difference in maximum customer lifetime value between genders, with females peaking at 44,856.11 and males at a much lower 32,677.34.
#
# Master’s Degree: Both genders show similar patterns in median customer lifetime value for Master’s degree holders.

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
